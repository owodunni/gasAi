# %%
from web3 import Web3

# %%
w3 = Web3(Web3.WebsocketProvider("ws://192.168.92.202:8546"))
w3.isConnected()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 w3 = Web3(Web3.WebsocketProvider("ws://192.168.92.202:8546"))
# ----> 2 w3.isConnected()
#
# File ~/.cache/pypoetry/virtualenvs/gasai-Lb-AIl4i-py3.10/lib/python3.10/site-packages/web3/main.py:343, in Web3.isConnected(self)
#     342 def isConnected(self) -> bool:
# --> 343     return self.provider.isConnected()
#
# File ~/.cache/pypoetry/virtualenvs/gasai-Lb-AIl4i-py3.10/lib/python3.10/site-packages/web3/providers/base.py:103, in JSONBaseProvider.isConnected(self)
#     101 def isConnected(self) -> bool:
#     102     try:
# --> 103         response = self.make_request(RPCEndpoint('web3_clientVersion'), [])
#     104     except IOError:
#     105         return False
#
# ...

# %%
w3.eth.get_
